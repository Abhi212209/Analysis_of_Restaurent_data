# %% [markdown]
# LEVEL=>1

# %% [markdown]
# TASK-1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Dataset .csv")

# %%
cuisine_data=df['Cuisines']

# %%
cuisine_count=cuisine_data.value_counts()

# %%
top_cuisines=cuisine_count.head(3)

# %%
total_restaurents=len(df)
percentage=(top_cuisines/total_restaurents)*100

# %%
plt.bar(percentage.index,percentage.values)
plt.xlabel("Cuisines")
plt.ylabel("Percenage")
plt.title("Top Three Cuisines in the Dataset")
plt.show()

# %%
plt.pie(top_cuisines,labels=top_cuisines.index,autopct="%1.1f%%")
plt.title("Top Three Cuisines in the Dataset")
plt.show()

# %% [markdown]
# TASK-2

# %%
restaurent=df.groupby("City")["Restaurant ID"].count()

city_with_highest_restaurents=restaurent.idxmax()
print("City with the highest number of restaurents:",city_with_highest_restaurents)
# Out:
# City with the highest number of restaurents: New Delhi

# %%
average_rating=df.groupby("City")["Aggregate rating"].mean()

# %%
average_rating.plot(kind="bar",figsize=(20,7))
plt.xlabel("City")
plt.ylabel("Average Rating")
plt.title("Average Rating for Restaurent in Each City")
plt.show()

# %%
city_with_highest_average_rating=average_rating.max()
print("city with highest average rating",city_with_highest_average_rating)
# Out:
# city with highest average rating 4.9

# %%
average_rating=df.groupby("City")["Aggregate rating"].mean()
print(average_rating)
# Out:
# City
# Abu Dhabi          4.300000
# Agra               3.965000
# Ahmedabad          4.161905
# Albany             3.555000
# Allahabad          3.395000
#                      ...
# Weirton            3.900000
# Wellington City    4.250000
# Winchester Bay     3.200000
# Yorkton            3.300000
# ��stanbul          4.292857
# Name: Aggregate rating, Length: 141, dtype: float64

# %% [markdown]
# TASK-3

# %%
Price_range_counts=df['Price range'].value_counts().sort_index()

# %%
Total_restaurants=len(df)
percentage_per_price_range=(Price_range_counts/Total_restaurants)*100

# %%
plt.bar(Price_range_counts.index,Price_range_counts.values)
plt.xlabel("Price Range")
plt.ylabel("Count")
plt.title("Distribution of price range")
plt.show()

# %%
print("Percentage of estaurents in each price range category:")
print(percentage_per_price_range)
# Out:
# Percentage of estaurents in each price range category:
# Price range
# 1    46.529159
# 2    32.593446
# 3    14.741912
# 4     6.135483
# Name: count, dtype: float64

# %% [markdown]
# TASK-4

# %%
total_restaurents=len(df)
restuarents_with_online_delivery=df['Has Online delivery'].value_counts().get('Yes',0)
percentage_with_online_delivery=(restuarents_with_online_delivery/total_restaurents)*100
print("percentage of restaurent that offer online delivery:",percentage_with_online_delivery)
# Out:
# percentage of restaurent that offer online delivery: 25.662234321013504

# %%
average_rating_with_online_delivery=df[df['Has Online delivery']=='Yes']['Aggregate rating'].mean()
average_rating_without_online_delivery=df[df['Has Online delivery']=='No']['Aggregate rating'].mean()
print('average_rating_without_online_delivery:',average_rating_with_online_delivery)
print('average_rating_without_online_delivery:',average_rating_without_online_delivery)
# Out:
# average_rating_without_online_delivery: 3.2488372093023257
# average_rating_without_online_delivery: 2.465295774647887

# %%
labels=['With Online Delivery','Without Online Delivery']
average_rating=[average_rating_with_online_delivery,average_rating_without_online_delivery]

plt.bar(labels,average_rating)
plt.xlabel("Online Delivery")
plt.ylabel("Average Rating")
plt.title("Comparison of Average rating")
plt.show()
